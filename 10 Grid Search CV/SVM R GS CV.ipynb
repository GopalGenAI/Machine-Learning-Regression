# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset = pd.get_dummies(dataset, drop_first = True, dtype = int)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
inde = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
dep = dataset [[ 'charges']]

# %%
#Automate the hypertune process
param_grid = {'kernel': ['linear', 'rbf', 'poly', 'sigmoid'], 'C': [100, 200, 300, 3000]} 
             
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3, n_jobs = -1)
grid.fit(inde, dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [100, 200, 300, 3000],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              verbose=3)

# %%
result = grid.cv_results_
print ("The R_Score value for best parameter {}.".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'C': 3000, 'kernel': 'linear'}.

# %%
table = pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.341542      0.018237         0.026114        0.001500      100
# 1        0.180344      0.002719         0.090050        0.002314      100
# 2        0.157811      0.005852         0.026921        0.001037      100
# 3        0.206483      0.007457         0.043607        0.000552      100
# 4        0.584578      0.240987         0.027397        0.001751      200
# 5        0.203570      0.025605         0.097457        0.007595      200
# 6        0.161249      0.003445         0.026774        0.000713      200
# 7        0.202749      0.001956         0.044039        0.001772      200
# 8        0.601478      0.046750         0.025039        0.000534      300
# 9        0.182183      0.006051         0.092484        0.009995      300
# 10       0.189903      0.015437         0.028946        0.003665      300
# 11       0.198292      0.002232         0.043330        0.000536      300
# 12       3.608528      0.884111         0.024073        0.006049     3000
# 13       0.197016      0.006127         0.088897        0.001493     3000
# 14       0.281715      0.021165         0.026740        0.000830     3000
# 15       0.197171      0.002583         0.044597        0.003036     3000
#
#    param_kernel                            params  split0_test_score  \
# 0        linear    {'C': 100, 'kernel': 'linear'}           0.559313
# 1           rbf       {'C': 100, 'kernel': 'rbf'}          -0.160182
# 2          poly      {'C': 100, 'kernel': 'poly'}          -0.132885
# 3       sigmoid   {'C': 100, 'kernel': 'sigmoid'}          -0.142455
# 4        linear    {'C': 200, 'kernel': 'linear'}           0.597540
# 5           rbf       {'C': 200, 'kernel': 'rbf'}          -0.164374
# 6          poly      {'C': 200, 'kernel': 'poly'}          -0.128637
# 7       sigmoid   {'C': 200, 'kernel': 'sigmoid'}          -0.199909
# 8        linear    {'C': 300, 'kernel': 'linear'}           0.617758
# 9           rbf       {'C': 300, 'kernel': 'rbf'}          -0.164126
# 10         poly      {'C': 300, 'kernel': 'poly'}          -0.123020
# 11      sigmoid   {'C': 300, 'kernel': 'sigmoid'}          -0.293600
# 12       linear   {'C': 3000, 'kernel': 'linear'}           0.677778
# 13          rbf      {'C': 3000, 'kernel': 'rbf'}          -0.128958
# 14         poly     {'C': 3000, 'kernel': 'poly'}           0.037700
# 15      sigmoid  {'C': 3000, 'kernel': 'sigmoid'}         -15.561853
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.521798           0.547691           0.538805
# 1           -0.107253          -0.123430          -0.137753
# 2           -0.082461          -0.129220          -0.139962
# 3           -0.160831          -0.117544          -0.137984
# 4            0.557538           0.586781           0.574764
# 5           -0.106426          -0.129065          -0.141841
# 6           -0.078468          -0.125003          -0.135484
# 7           -0.231836          -0.180189          -0.202001
# 8            0.575264           0.603577           0.594633
# 9           -0.107700          -0.128180          -0.139809
# 10          -0.073269          -0.119364          -0.130550
# 11          -0.348392          -0.278722          -0.298268
# 12           0.626814           0.732806           0.633479
# 13          -0.075578          -0.100199          -0.116051
# 14           0.098496           0.049291           0.035615
# 15         -20.498908         -17.095474         -16.750877
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.508518         0.535225        0.018122                4
# 1           -0.209551        -0.147634        0.035511               11
# 2           -0.189219        -0.134749        0.033948                9
# 3           -0.130402        -0.137843        0.014263               10
# 4            0.555420         0.574409        0.016331                3
# 5           -0.216445        -0.151630        0.037448               13
# 6           -0.182919        -0.130102        0.033205                8
# 7           -0.180953        -0.198978        0.018802               14
# 8            0.575552         0.593357        0.016406                2
# 9           -0.216221        -0.151207        0.037274               12
# 10          -0.177024        -0.124645        0.033011                7
# 11          -0.260641        -0.295925        0.029342               15
# 12           0.698692         0.673914        0.039876                1
# 13          -0.179304        -0.120018        0.034578                6
# 14          -0.020924         0.040035        0.038064                5
# 15         -15.012168       -16.983856        1.914783               16

# %%
Future_Prediction=grid.predict([[34,23,1,1,1]])
print("Future_prediction= {}".format(Future_Prediction))
# Out:
# Future_prediction= [36032.61216666]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

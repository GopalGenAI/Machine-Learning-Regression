# %%
import pickle

# %%
#The best R_score value for parameter: {'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'init': None, 
#'learning_rate': 0.1, 'loss': 'huber', 'max_depth': 3, 
#'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2,
#'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_iter_no_change': None, 'random_state': None, 
#'subsample': 1.0, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False

param_grid = {
    'alpha': [0.9],
    'ccp_alpha': [0.0],
    'criterion': ['squared_error'],
    'init': [None],
    'learning_rate': [0.1],
    'loss': ['huber'],
    'max_depth': [3],
    'max_features': [None],
    'max_leaf_nodes': [None],
    'min_impurity_decrease': [0.0],
    'min_samples_leaf': [1],
    'min_samples_split': [2],
    'min_weight_fraction_leaf': [0.0],
    'n_estimators': [100],
    'n_iter_no_change': [None],
    'random_state': [None],
    'subsample': [1.0],
    'tol': [0.0001],
    'validation_fraction': [0.1],
    'verbose': [0],
    'warm_start': [False]
}

# %%
loaded_model = pickle.load(open("finalized_model_XGbgscv.sav", 'rb'))
result = loaded_model.predict([[32, 22, 1, 1, 0]])
result
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([3979.6881602])

# %%
import pickle

#The best R_Score value for paratmer {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 1000, 'subsample': 1.0}.

param_grid = {
    'colsample_bytree': [1.0],
    'learning_rate': [0.1],
    'max_depth': [9],
    'n_estimators': [1000],
    'subsample': [1.0]
}

# %%
loaded_model = pickle.load(open('finalized_model_XGboostGSCV.sav', 'rb'))
result = loaded_model.predict([[20, 14.3, 0, 1, 1]])
result
# Out:
# array([15620.527], dtype=float32)

# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_mode_ada.sav", 'rb'))
result = loaded_model.predict([[13, 14, 5, 1, 0]])
result
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# array([10131.52448663])
